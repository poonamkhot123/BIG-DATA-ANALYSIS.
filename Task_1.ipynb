# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/BIG-DATA-ANALYSIS./blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dask[complete] openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-902b822e-412a-448b-a25c-064985359447" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-902b822e-412a-448b-a25c-064985359447">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import shutil
shutil.move("Mobile Sales Data.xlsx", "/content/Mobile_Sales_Data.xlsx")
# Out:
# '/content/Mobile_Sales_Data.xlsx'

# %%
import pandas as pd

# Load Excel and convert to CSV
file_path = "/content/Mobile_Sales_Data.xlsx"
df = pd.read_excel(file_path)
df.to_csv("/content/Mobile_Sales_Data.csv", index=False)

# %%
import dask.dataframe as dd

# Load CSV file into Dask
dask_df = dd.read_csv("/content/Mobile_Sales_Data.csv")

# Show first 5 rows
dask_df.head()
# Out:
#    Transaction ID  Day  Month  Year  Day Name    Brand  Units Sold  \
# 0               1    9     10  2021       Sat   Xiaomi           6
# 1               2    9     10  2021  Saturday     Vivo           6
# 2               3    9     10  2021  Saturday     Vivo           8
# 3               4   10     10  2021    Sunday   Xiaomi           5
# 4               5   10     10  2021    Sunday  OnePlus           3
#
#    Price Per Unit     Customer Name  Customer Age       City Payment Method  \
# 0        10174.70      Lalita Ahuja            38   Ludhiana            UPI
# 1        10565.19      Sneha Sharma            37      Delhi    Credit Card
# 2        58527.58  Radha Srivastava            40     Mumbai            UPI
# 3        25563.98     Bhavana Arora            21     Mumbai    Credit Card
# 4        48168.02       Sneha Mehta            38  Gorakhpur           Cash
#
#    Customer Ratings   Mobile Model
# 0                 5  Redmi Note 10
# ...

# %%
dask_df.dtypes
# Out:
# Transaction ID                int64
# Day                           int64
# Month                         int64
# Year                          int64
# Day Name            string[pyarrow]
# Brand               string[pyarrow]
# Units Sold                    int64
# Price Per Unit              float64
# Customer Name       string[pyarrow]
# Customer Age                  int64
# City                string[pyarrow]
# Payment Method      string[pyarrow]
# Customer Ratings              int64
# Mobile Model        string[pyarrow]
# dtype: object

# %%
import dask.dataframe as dd

# Load CSV file into Dask
dask_df = dd.read_csv("/content/Mobile_Sales_Data.csv")

# Print the columns of the Dask DataFrame
print(dask_df.columns)

# Calculate the average price by category if 'Category' column is present
if "Category" in dask_df.columns:
    avg_price_category = dask_df.groupby("Category")["Price"].mean().compute()
    print(avg_price_category)
else:
    print("Column 'Category' not found in the DataFrame. Please check your data.")
# Out:
# Index(['Transaction ID', 'Day', 'Month', 'Year', 'Day Name', 'Brand',
#        'Units Sold', 'Price Per Unit', 'Customer Name', 'Customer Age', 'City',
#        'Payment Method', 'Customer Ratings', 'Mobile Model'],
#       dtype='object')
# Column 'Category' not found in the DataFrame. Please check your data.

# %%
import dask.dataframe as dd

# Load CSV file into Dask to check columns
dask_df = dd.read_csv("/content/Mobile_Sales_Data.csv")

# 1. Check column names and correct if necessary
print(dask_df.columns)  # Print the columns to verify the correct name
# If the column is
# Out:
# Index(['Transaction ID', 'Day', 'Month', 'Year', 'Day Name', 'Brand',
#        'Units Sold', 'Price Per Unit', 'Customer Name', 'Customer Age', 'City',
#        'Payment Method', 'Customer Ratings', 'Mobile Model'],
#       dtype='object')

# %%
# Load CSV file into Dask to check columns
dask_df = dd.read_csv("/content/Mobile_Sales_Data.csv")

# 1. Check column names and correct if necessary
print(dask_df.columns)  # Print the columns to verify the correct name

# Assuming the date column is named 'Order Date', but verify from the printed columns
date_column_name = "Order Date"  # Replace with the actual column name from the printed output if different

# Convert the date column to datetime format
try:
    dask_df["Date"] = dd.to_datetime(dask_df[date_column_name])
except KeyError:
    print(f"Column '{date_column_name}' not found. Please check the column name.")
    # Here, you can either exit the script or handle the error in another way
    # For example, you might try to find the correct column name based on partial matches

# Extract month from the 'Date' column if it was successfully created
if "Date" in dask_df.columns:
    dask_df["Month"] = dask_df["Date"].dt.month

    # Group by month and sum sales
    monthly_sales = dask_df.groupby("Month")["Sales"].sum().compute()
    print(monthly_sales)
# Out:
# Index(['Transaction ID', 'Day', 'Month', 'Year', 'Day Name', 'Brand',
#        'Units Sold', 'Price Per Unit', 'Customer Name', 'Customer Age', 'City',
#        'Payment Method', 'Customer Ratings', 'Mobile Model'],
#       dtype='object')
# Column 'Order Date' not found. Please check the column name.

# %%
import shutil
import os

# Remove the directory if it exists
output_path = "/content/output_sales.csv"
if os.path.exists(output_path):
    if os.path.isdir(output_path):
        shutil.rmtree(output_path)  # Use shutil.rmtree to remove a directory
    else:
        os.remove(output_path)  # Remove file if it exists

# Save to CSV using Dask's to_csv with single_file option
dd.to_csv(dask_df, output_path, index=False, single_file=True)
# Out:
# ['/content/output_sales.csv']

# %%
from google.colab import files
files.download("/content/output_sales.csv")
